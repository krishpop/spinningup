# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
load_path = '../data/scaled_actions/scaled_actions_s0/progress.txt'
df = pd.read_csv(load_path, sep='\t')

df.plot(x='TotalEnvInteracts', y='SuccessRateVal')
steps = np.linspace(0., .6, 10)
plt.scatter(np.arange(0, df.TotalEnvInteracts.max(), df.TotalEnvInteracts.max()//10), steps)

# %%
np.arange(0, .75, 0.25)
# Out:
# array([0.  , 0.25, 0.5 ])

# %%
n = 10
step_rates = np.linspace(0, 0.8, 10)

# %%
step_rates.shape
# Out:
# (25,)

# %%
steps, rate = df[['TotalEnvInteracts', 'SuccessRateVal']].max().values
np.arange(0, rate, df['Epoch'].max()+1)
# Out:
# array([0.])

# %%
from spinup import ppo_pytorch as ppo
from rrc_simulation.control.control_policy import ImpedanceControllerPolicy

# %%
gamma = 0.99
lam = 0.97
spe = int(1e6)

buf = PPOBuffer(obs_dim, act_dim, spe, gamma, lam)

# %%
ImpedenceControllerPolicy()
